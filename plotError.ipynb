# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the CSV file
df = pd.read_csv('output.csv')

# %%
# Assuming you want the jth element (Python is zero-indexed, so jth means (j-1) in Python terms)
# j = 3  # for example, to access the 3rd column, adjust this according to your needs

# Extract the jth column (subtract 1 because Python indexing starts at 0)
# roll = df.iloc[:, j]
# pitch = df.iloc[:, j+1]
# yaw = df.iloc[:, j+2]

# Create a linspace from 0 to 1, length equal to the number of rows
time = np.linspace(0, 1, len(df))

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plotting
plt.plot(df.iloc[:, 3], df.iloc[:, 4], df.iloc[:, 5], marker='o', label='Roll')  # Using 'o' as marker for each data point
# plt.plot(time, pitch, marker='*', label='Pitch')  # Using '*' as marker for each data point
# plt.plot(time, yaw, marker='x', label='Yaw')  # Using 'x' as marker for each data point
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')
plt.legend()
plt.title('Plot of jth Element of Every Row against Linspace')
plt.show()
